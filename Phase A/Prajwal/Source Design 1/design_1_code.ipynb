# %% [markdown]
# ## **Importing necessary packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Data Preprocessing**

# %%
df = pd.read_csv('C:\\Users\\prajw\\OneDrive - Swansea University\\globalterrorismdb_0718dist.csv' , on_bad_lines = 'skip', encoding = 'latin')
pd.set_option("display.max_columns", 500)

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                     'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                     'nwound': 'Wounded','gname':'Group','targtype1_txt':'Target_type',
                     'weaptype1_txt':'Weapon_type','motive':'Motive'
                    },inplace=True)
df_new = df[['eventid','Year','Month','Day','Country','Region','state','city','latitude','longitude','AttackType','Killed','Wounded',
            'Target','Group','Target_type','Weapon_type','Motive','success']]

# %%
df_new.shape
# Out:
# (181691, 19)

# %%
df_new['Casualties']=df_new['Killed']+df_new['Wounded']

# %%
df_new.shape
# Out:
# (181691, 20)

# %%
df_new.head()
# Out:
#         eventid  Year  Month  Day             Country  \
# 0  197000000001  1970      7    2  Dominican Republic
# 1  197000000002  1970      0    0              Mexico
# 2  197001000001  1970      1    0         Philippines
# 3  197001000002  1970      1    0              Greece
# 4  197001000003  1970      1    0               Japan
#
#                         Region    state           city   latitude   longitude  \
# 0  Central America & Caribbean      NaN  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# 2               Southeast Asia   Tarlac        Unknown  15.478598  120.599741
# 3               Western Europe   Attica         Athens  37.997490   23.762728
# 4                    East Asia  Fukouka        Fukouka  33.580412  130.396361
#
#                        AttackType  Killed  Wounded                   Target  \
# 0                   Assassination     1.0      0.0             Julio Guzman
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   eventid      181691 non-null  int64
#  1   Year         181691 non-null  int64
#  2   Month        181691 non-null  int64
#  3   Day          181691 non-null  int64
#  4   Country      181691 non-null  object
#  5   Region       181691 non-null  object
#  6   state        181270 non-null  object
#  7   city         181257 non-null  object
#  8   latitude     177135 non-null  float64
#  9   longitude    177134 non-null  float64
#  10  AttackType   181691 non-null  object
#  11  Killed       171378 non-null  float64
#  12  Wounded      165380 non-null  float64
#  13  Target       181055 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
#  17  Motive       50561 non-null   object
# ...

# %% [markdown]
# ## **Data Cleaning**

# %%
print(df_new.isnull().sum())
# Out:
# eventid             0
# Year                0
# Month               0
# Day                 0
# Country             0
# Region              0
# state             421
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# success             0
# Casualties      16874
# dtype: int64

# %% [markdown]
# "Number of Killed" contains numerical data, hence let us fill the NA Values by filling 0 and "City" has the Categorical Data and hence let us fill NA values using "unknown" parameter

# %%
df_new['city'].fillna('Unknown',inplace = True)
df_new['Killed'].fillna(0,inplace=True)
df_new['Wounded'].fillna(0,inplace=True)
df_new['Casualties'].fillna(0,inplace=True)
df_new['state'].fillna(0,inplace=True)
df_new['latitude'].fillna(0,inplace=True)
df_new['longitude'].fillna(0,inplace=True)
df_new['Target'].fillna(0,inplace=True)
df_new['Motive'].fillna(0,inplace=True)

# %%
df_new.isnull().sum()
# Out:
# eventid        0
# Year           0
# Month          0
# Day            0
# Country        0
# Region         0
# state          0
# city           0
# latitude       0
# longitude      0
# AttackType     0
# Killed         0
# Wounded        0
# Target         0
# Group          0
# Target_type    0
# Weapon_type    0
# Motive         0
# success        0
# Casualties     0
# dtype: int64

# %% [markdown]
#  Carefully observing the "Number of Killed", one can also see that this contans float64 datatype which doesn't make more sense, hence converting it into 'int64' datatype

# %%
df_new['Killed'] = df_new['Killed'].astype(int)
df_new['Killed']
df_new['Casualties'] = df_new['Casualties'].astype(int)
df_new['Casualties']
# Out:
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 181686    3
# 181687    9
# 181688    0
# 181689    0
# 181690    0
# Name: Casualties, Length: 181691, dtype: int32

# %%
df_new.head()
# Out:
#         eventid  Year  Month  Day             Country  \
# 0  197000000001  1970      7    2  Dominican Republic
# 1  197000000002  1970      0    0              Mexico
# 2  197001000001  1970      1    0         Philippines
# 3  197001000002  1970      1    0              Greece
# 4  197001000003  1970      1    0               Japan
#
#                         Region    state           city   latitude   longitude  \
# 0  Central America & Caribbean        0  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# 2               Southeast Asia   Tarlac        Unknown  15.478598  120.599741
# 3               Western Europe   Attica         Athens  37.997490   23.762728
# 4                    East Asia  Fukouka        Fukouka  33.580412  130.396361
#
#                        AttackType  Killed  Wounded                   Target  \
# 0                   Assassination       1      0.0             Julio Guzman
# ...

# %% [markdown]
# Let us now move to working with duplicate values

# %%
df_new.duplicated().sum()
df_new.drop_duplicates()
# Out:
#              eventid  Year  Month  Day             Country  \
# 0       197000000001  1970      7    2  Dominican Republic
# 1       197000000002  1970      0    0              Mexico
# 2       197001000001  1970      1    0         Philippines
# 3       197001000002  1970      1    0              Greece
# 4       197001000003  1970      1    0               Japan
# ...              ...   ...    ...  ...                 ...
# 181686  201712310022  2017     12   31             Somalia
# 181687  201712310029  2017     12   31               Syria
# 181688  201712310030  2017     12   31         Philippines
# 181689  201712310031  2017     12   31               India
# 181690  201712310032  2017     12   31         Philippines
#
#                              Region            state           city  \
# 0       Central America & Caribbean                0  Santo Domingo
# 1                     North America          Federal    Mexico city
# ...

# %% [markdown]
# ## **Exploratory Data Analysis and Visualisation**

# %% [markdown]
# ### **Violin Plots**

# %%
countries_to_include = [
    'Russia', 'Ukraine',  # From Eastern Europe
    'United Kingdom', 'Pakistan', 'Afghanistan', 'India',  # From Western Europe
    'United States',  # From North America
    'Iraq', 'Yemen'  # From Middle East & North Africa
]

filtered_df = df_new[df_new['Country'].isin(countries_to_include)]

am_dt = filtered_df.groupby(['Country', 'Year'])['Killed'].sum().reset_index()

figsize = (12, 1 * len(countries_to_include))
plt.figure(figsize=figsize)
plt.grid(True)
palette = 'dark'
violin = sns.violinplot(data=am_dt, x='Killed', y='Country', inner='box', palette=palette, scale='width', cut=0.1)
plt.grid(True, linestyle='--', linewidth=0.6, color='gray')
plt.title('Terrorist Incidents by Country', fontsize=20)
plt.xlabel('Number of People Killed', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.yticks(fontsize=18)
plt.savefig('Aesthetic_Violinplot_BoxVersion.png', dpi=400)
plt.show()
